# %%
# Imports
from pymongo import MongoClient
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import json

# Connect to MongoDB
client = MongoClient('mongodb://localhost:27017')
db = client['collaborativefilteringtest']  # Database name
users_collection = db['users']
posts_collection = db['posts']
likes_collection = db['likes']
answers_collection = db['answers']  # Add answers collection

# %%
# Fetch data from MongoDB
users = list(users_collection.find())
query = 'kesehatan'
search_query = {
        "$or": [
            { "date": { "$regex": query, "$options": "i" } },
            { "question": { "$regex": query, "$options": "i" } },
            { "topic": { "$regex": query, "$options": "i" } },
            { "id_user": { "$regex": query, "$options": "i" } },
            { "title": { "$regex": query, "$options": "i" } },
            { "post_pic": { "$regex": query, "$options": "i" } }
        ]
    }
posts = list(posts_collection.find(search_query))
if not posts:
    posts = list(posts_collection.find())
        
# Get likes for filtered posts
post_ids = [str(post['_id']) for post in posts]
print("Ini post_ids :", post_ids)
likes = list(likes_collection.find({'post_id': {'$in': post_ids}}))
print("Ini likes :", likes)

# Get answers for filtered posts
answers = list(answers_collection.find({'post_id': {'$in': post_ids}}))
print("Ini answers :", answers)

# Create DataFrame for likes and answers
likes_df = pd.DataFrame(likes)
answers_df = pd.DataFrame(answers)

# Add a column 'interaction' to likes and answers DataFrame
likes_df['interaction'] = 1
answers_df['interaction'] = 1

# Combine likes and answers DataFrame
interactions_df = pd.concat([likes_df[['user_id', 'post_id', 'interaction']], 
                            answers_df[['user_id', 'post_id', 'interaction']]])
# Fetch post titles
post_titles = {str(post['_id']): post['title'] for post in posts}
user_username = {str(user['_id']): user['username'] for user in users}

# Replace post_id with title in interactions_df
interactions_df['post_id'] = interactions_df['post_id'].apply(lambda x: post_titles[str(x)])
interactions_df['user_id'] = interactions_df['user_id'].apply(lambda x: user_username[str(x)])

# Pivot table to create user-item matrix
user_item_matrix = interactions_df.pivot_table(index='user_id', columns='post_id', values='interaction', fill_value=0)

# Convert user-item matrix to numpy array
ratings_matrix = user_item_matrix.to_numpy()

# Calculate cosine similarity between users
user_similarity = cosine_similarity(ratings_matrix)

# Visualize the user-item matrix
plt.figure(figsize=(10, 8))
sns.heatmap(user_item_matrix, cmap='viridis', cbar=True)
plt.title('User-Item Interaction Matrix')
plt.xlabel('Posts')
plt.ylabel('Users')
plt.show()

# Visualize the user similarity matrix
plt.figure(figsize=(10, 8))
sns.heatmap(user_similarity, cmap='coolwarm', cbar=True)
plt.title('User Similarity Matrix')
plt.xlabel('Users')
plt.ylabel('Users')
plt.show()
# Out:
# Ini post_ids : ['66a1b0f10aa35f5c18c123a4', '66a1b0f10aa35f5c18c123a5', '66a1b0f10aa35f5c18c123a7', '66a1b0f10aa35f5c18c123ab', '66a1b0f10aa35f5c18c123ac', '66a1b0f10aa35f5c18c123b0', '66a1b0f10aa35f5c18c123b3']
# Ini likes : [{'_id': ObjectId('669ec5602d7754c58c0ac9cd'), 'user_id': '669c0b8e2ea43ac3b0c83be4', 'post_id': '66a1b0f10aa35f5c18c123b0'}, {'_id': ObjectId('64b1b0f10aa35f5c18c123b2'), 'user_id': '669c0b8e2ea43ac3b0c83bd2', 'post_id': '66a1b0f10aa35f5c18c123a4'}, {'_id': ObjectId('64b1b0f10aa35f5c18c123b3'), 'user_id': '669c0b8e2ea43ac3b0c83bd2', 'post_id': '66a1b0f10aa35f5c18c123a7'}, {'_id': ObjectId('64b1b0f10aa35f5c18c123b5'), 'user_id': '669c0b8e2ea43ac3b0c83bd3', 'post_id': '66a1b0f10aa35f5c18c123a5'}, {'_id': ObjectId('64b1b0f10aa35f5c18c123bb'), 'user_id': '669c0b8e2ea43ac3b0c83bd5', 'post_id': '66a1b0f10aa35f5c18c123a4'}, {'_id': ObjectId('64b1b0f10aa35f5c18c123bd'), 'user_id': '669c0b8e2ea43ac3b0c83bd5', 'post_id': '66a1b0f10aa35f5c18c123ac'}, {'_id': ObjectId('669ec6fa2d7754c58c0ac9d0'), 'user_id': '669c0b8e2ea43ac3b0c83be4', 'post_id': '66a1b0f10aa35f5c18c123a7'}, {'_id': ObjectId('669ec6fc2d7754c58c0ac9d1'), 'user_id': '669c0b8e2ea43ac3b0c83be4', 'post_id': '66a1b0f10aa35f5c18c123ac'}, {'_id': ObjectId('669f13faf0a9ccc427857283'), 'user_id': '669c0bb23cfd9ea81c694fc8', 'post_id': '66a1b0f10aa35f5c18c123b3'}, {'_id': ObjectId('669f6e0426728779507c344d'), 'user_id': '669c0b8e2ea43ac3b0c83be4', 'post_id': '66a1b0f10aa35f5c18c123a4'}, {'_id': ObjectId('669f708126728779507c344e'), 'user_id': '669c0b8e2ea43ac3b0c83be4', 'post_id': '66a1b0f10aa35f5c18c123b3'}, {'_id': ObjectId('66a3531f4773f94424f22ab8'), 'user_id': '66a0ae5660cb65cbc9feb870', 'post_id': '66a1b0f10aa35f5c18c123ab'}, {'_id': ObjectId('66a353454773f94424f22aba'), 'user_id': '66a0ae5660cb65cbc9feb870', 'post_id': '66a1b0f10aa35f5c18c123a7'}, {'_id': ObjectId('66a3534b4773f94424f22abb'), 'user_id': '66a0ae5660cb65cbc9feb870', 'post_id': '66a1b0f10aa35f5c18c123ac'}, {'_id': ObjectId('66a353534773f94424f22abc'), 'user_id': '66a0ae5660cb65cbc9feb870', 'post_id': '66a1b0f10aa35f5c18c123b3'}, {'_id': ObjectId('66a35db2e68f7c52d189b514'), 'user_id': '66a0ae5660cb65cbc9feb870', 'post_id': '66a1b0f10aa35f5c18c123a4'}]
# Ini answers : [{'_id': ObjectId('669ec82e2d7754c58c0ac9d2'), 'post_id': '66a1b0f10aa35f5c18c123a4', 'user_id': '669c0b8e2ea43ac3b0c83be4', 'content': 'test', 'answer_pic': None, 'date': '2024-07-23 04:59:26'}, {'_id': ObjectId('669ec8372d7754c58c0ac9d3'), 'post_id': '66a1b0f10aa35f5c18c123a4', 'user_id': '669c0b8e2ea43ac3b0c83be4', 'content': 'testsett', 'answer_pic': '20240723045935_Screenshot_1.png', 'date': '2024-07-23 04:59:35'}, {'_id': ObjectId('669f61cde631f6bd2e43496f'), 'post_id': '66a1b0f10aa35f5c18c123a4', 'user_id': '669c0b8e2ea43ac3b0c83be4', 'content': 'wafawfawf', 'answer_pic': '20240723155453_Screenshot_2024-07-21_164816.png', 'date': '2024-07-23 15:54:53'}, {'_id': ObjectId('66a0a51f59336f9204ed0a5e'), 'post_id': '66a1b0f10aa35f5c18c123b0', 'user_id': '669c0b8e2ea43ac3b0c83be4', 'content': 'test', 'answer_pic': None, 'date': '2024-07-24 14:54:23'}, {'_id': ObjectId('66a0a52159336f9204ed0a5f'), 'post_id': '66a1b0f10aa35f5c18c123b0', 'user_id': '669c0b8e2ea43ac3b0c83be4', 'content': 'test', 'answer_pic': None, 'date': '2024-07-24 14:54:25'}, {'_id': ObjectId('66a102f6420af1ba8d7156fc'), 'post_id': '66a1b0f10aa35f5c18c123a4', 'user_id': '66a0ae5660cb65cbc9feb870', 'content': 'test', 'answer_pic': None, 'date': '2024-07-24 21:34:46'}, {'_id': ObjectId('66a1145a75dbb53dfe4eca8c'), 'post_id': '66a1b0f10aa35f5c18c123ac', 'user_id': '66a0ae5660cb65cbc9feb870', 'content': 'fffff', 'answer_pic': '20240724224858_Screenshot_1.png', 'date': '2024-07-24 22:48:58'}, {'_id': ObjectId('66a11a795f837f5bc76eb0c9'), 'post_id': '66a1b0f10aa35f5c18c123ac', 'user_id': '66a0ae5660cb65cbc9feb870', 'content': 'wafaf', 'answer_pic': '20240725004803_Screenshot_1.png', 'date': '2024-07-24 23:15:05'}, {'_id': ObjectId('66a12ac5e19d6b83338b3220'), 'post_id': '66a1b0f10aa35f5c18c123ac', 'user_id': '66a0ae5660cb65cbc9feb870', 'content': 'test', 'answer_pic': '20240725004752_Screenshot_1.png', 'date': '2024-07-25 00:24:37'}, {'_id': ObjectId('66a13267e19d6b83338b3221'), 'post_id': '66a1b0f10aa35f5c18c123ac', 'user_id': '66a0ae5660cb65cbc9feb870', 'content': 'afawfwaf', 'answer_pic': '20240725013652_Screenshot_2024-07-21_164816.png', 'date': '2024-07-25 00:57:11'}, {'_id': ObjectId('66a13bbc286c1fff2557727e'), 'post_id': '66a1b0f10aa35f5c18c123ac', 'user_id': '66a0ae5660cb65cbc9feb870', 'content': 'gshsh', 'answer_pic': '20240725013705_Screenshot_1.png', 'date': '2024-07-25 01:37:00'}]

# %%
# Function to recommend posts for a given user based on similar users' likes
def recommend_posts(user_idx, num_recommendations=3):
    sim_scores = user_similarity[user_idx]
    similar_users = np.argsort(sim_scores)[::-1][1:]  # Exclude the user itself

    post_scores = np.zeros(ratings_matrix.shape[1])

    for similar_user in similar_users:
        post_scores += sim_scores[similar_user] * ratings_matrix[similar_user]

    post_scores[ratings_matrix[user_idx] > 0] = 0  # Remove already liked/answered posts
    recommended_post_indices = np.argsort(post_scores)[::-1][:num_recommendations]
    
    print(recommended_post_indices)
    return post_scores, recommended_post_indices

# %%
recommendations = {}
post_scores_dict = {}
for user_id in user_item_matrix.index:
    user_idx = list(user_item_matrix.index).index(user_id)
    post_scores, recommended_posts = recommend_posts(user_idx, num_recommendations=3)
    recommended_post_ids = [user_item_matrix.columns[post_idx] for post_idx in recommended_posts]
    recommendations[str(user_id)] = recommended_post_ids
    post_scores_dict[str(user_id)] = post_scores.tolist()  # Save the scores as a list

# Save recommendations to a JSON file
with open('search-recommendations-test.json', 'w') as f:
    json.dump(recommendations, f)

# Save post scores to a JSON file
with open('search-post_scores.json', 'w') as f:
    json.dump(post_scores_dict, f)

# Visualize the post scores for the first user
user_id = list(user_item_matrix.index)[0]
user_idx = list(user_item_matrix.index).index(user_id)
post_scores, _ = recommend_posts(user_idx, num_recommendations=3)

plt.figure(figsize=(12, 6))
sns.barplot(x=user_item_matrix.columns, y=post_scores, palette='viridis')
plt.title(f'Post Scores for User {user_id}')
plt.xlabel('Posts')
plt.ylabel('Scores')
plt.xticks(rotation=90)
plt.show()
# Out:
# [5 1 2]
# [6 5 4]
# [1 0 6]
# [5 0 6]
# [3 5 6]
# [6 5 4]
# [5 1 2]
# C:\Users\estar\AppData\Local\Temp\ipykernel_13652\3291039522.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=user_item_matrix.columns, y=post_scores, palette='viridis')
